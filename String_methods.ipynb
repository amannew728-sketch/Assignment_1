# %%
string = "This is python class"

# %% [markdown]
# # string.capitalize()

# %%
string = "This is python class"
string.capitalize()
# Out:
# 'This is python class'

# %% [markdown]
# # string.casefold()

# %%
string.casefold()
# Out:
# 'this is python class'

# %% [markdown]
# # string.lower()

# %%
string.lower()
# Out:
# 'this is python class'

# %% [markdown]
# # string.upper()

# %%
string.upper()
# Out:
# 'THIS IS PYTHON CLASS'

# %% [markdown]
# # string.swapcase()

# %%
string.swapcase()
# Out:
# 'tHIS IS PYTHON CLASS'

# %% [markdown]
# # string.title()

# %%
string.title()
# Out:
# 'This Is Python Class'

# %% [markdown]
# # string.find(sub)

# %%
string.find("a")  # 1
# Out:
# 17

# %% [markdown]
# # string.rfind(sub)

# %%
string.rfind("l")  # 3
# Out:
# 16

# %% [markdown]
# # string.index(sub)

# %%
string.index("t")  # 1
# Out:
# 10

# %% [markdown]
# # string.rindex(sub)

# %%
string.rindex("h")
# Out:
# 11

# %% [markdown]
# # string.count(sub)

# %%
string.count("a")
# Out:
# 1

# %% [markdown]
# # string.startswith(prefix)

# %%
string.startswith("la")  # True
# Out:
# False

# %% [markdown]
# # string.endswith(suffix)

# %%
s = "This"
print(s.endswith("is"))  # True
# Out:
# True
